# %% [markdown]
# <a href="https://colab.research.google.com/github/carol-lanzu/ML_models/blob/main/regression_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Red wine quality dataset: regression dataset

# %%
import pandas
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from yellowbrick.regressor import PredictionError

data = pandas.read_csv('/content/winequality-red.csv')

# %%
y = data.iloc[:,11].values
X = data.iloc[:,0:11].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
# Data handling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Random Forest Regression

# %%
model = RandomForestRegressor(random_state=0)
model.fit(X_train_scaled, y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
model.score(X_test_scaled, y_test)
# Out:
# 0.4420271804153757

# %%
visualizer = PredictionError(model)
visualizer.fit(X_train_scaled, y_train)
visualizer.score(X_test_scaled, y_test)
visualizer.show()
# Out:
# <Axes: title={'center': 'Prediction Error for RandomForestRegressor'}, xlabel='$y$', ylabel='$\\hat{y}$'>

# %% [markdown]
# ## Linear Regression

# %%
model = LinearRegression()
model = model.fit(X_train_scaled, y_train)

# %%
model.score(X_test_scaled,y_test)
# Out:
# 0.34542438124562835

# %%
visualizer = PredictionError(model)
visualizer.fit(X_train_scaled, y_train)
visualizer.score(X_test_scaled, y_test)
visualizer.show()
# Out:
# <Axes: title={'center': 'Prediction Error for LinearRegression'}, xlabel='$y$', ylabel='$\\hat{y}$'>
